# %% [markdown]
# ## Analysis_Caffeine
# This project demonstrated the usage of pkdb for the test substance caffeine.
# ### Data Sources
# - pkdb rest api : "http://0.0.0.0:8000/api/v1/"
#
# ### Outputs:
# - data/processed/outputs.tsv
# - data/processed/timecourses.tsv
# - data/processed/interventions.tsv
# - data/processed/individuals.tsv
# - data/processed/groups.tsv
#
# #### Groups and Individuals
# - data/processed/all_subjects.tsv
#
# ### Merged Dataframes
# - data/processed/all_subjects.tsv
#
# ### Normalized Dataframes
# - data/processed/all_subjects.tsv
#
# ### Changes
# - 11-29-2018 : Started project

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import PkdbModel , Preprocessed
import pandas as pd

# %%
queries = ['outputs','timecourses','interventions','individuals','groups']

# %% [markdown]
# ### Query, Process and Save
# Json data is loaded, transformed to dataframes, preprocessed and saved as tab seperated files.

# %%
for pk_instance in queries:
    pk_instance = PkdbModel(pk_instance)  
    pk_instance.load()
    pk_instance.preprocess()
    pk_instance.save()
    pk_instance.report()
# Out:
# ____________________________________________________________
# Name: outputs
# Loaded: True
# Preprocessed: True
# saved: True
# outputs were succsesfully saved to </home/janek/Dev/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/outputs.tsv>
# ____________________________________________________________
# Name: timecourses
# Loaded: True
# Preprocessed: True
# saved: True
# timecourses were succsesfully saved to </home/janek/Dev/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/timecourses.tsv>
# ____________________________________________________________
# Name: interventions
# Loaded: True
# Preprocessed: True
# saved: True
# interventions were succsesfully saved to </home/janek/Dev/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/interventions.tsv>
# ____________________________________________________________
# Name: individuals
# Loaded: True
# Preprocessed: True
# saved: True
# individuals were succsesfully saved to </home/janek/Dev/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/individuals.tsv>
# ____________________________________________________________
# Name: groups
# Loaded: True
# Preprocessed: True
# saved: True
# groups were succsesfully saved to </home/janek/Dev/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/groups.tsv>

# %% [markdown]
# ### Convert Units

# %%
this_data = PkdbModel('timecourses',destination='1-preprocessed')
this_data.read()
this_data.data.groupby(["pktype","unit"]).count()
# Out:
#                       tissue  time_unit  time  substance_name  interventions  \
# pktype        unit
# concentration ng/g         2          2     2               2              2
#               nmol/l       2          2     2               2              2
#               µg/ml      146        146   146             146            146
#               µmol/l       8          8     8               8              8
# cum_amount    µmol         8          8     8               8              8
# ratio         -           20         20    20              20             20
#
#                       auc_end  kel  figure  group_pk  mean  individual_pk  \
# pktype        unit
# concentration ng/g          2    2       2         2     0              0
#               nmol/l        2    2       2         2     2              0
#               µg/ml       141  135      71        58    58             88
#               µmol/l        1    1       8         8     8              0
# cum_amount    µmol          8    0       8         8     8              0
# ratio         -            12    3      19        20    15              0
#
#                       value  se  cv  sd  median  max  min
# pktype        unit
# concentration ng/g        0   2   0   2       2    0    0
#               nmol/l      0   2   2   2       0    0    0
#               µg/ml      88  43  43  35       0    0    0
#               µmol/l      0   8   8   8       0    0    0
# cum_amount    µmol        0   0   0   0       0    0    0
# ratio         -           0  12  11  12       7    6    6

# %% [markdown]
# ### Merge
#  - merge individuals and groups  --> all_subjects,
#  - merge outputs and timecourses --> all_results,
#  - merge all_results with interventions and individuals  --> individuals_complete,
#  - merge all_results with interventions and groups  --> groups_complete,
#  - merge all_results with interventions and all_subjects -->  all_complete

# %%
prepocessed = Preprocessed()

# %%
prepocessed.read()
prepocessed.merge()
prepocessed.save()
# Out:
# /home/janek/Dev/pkdb/notebooks/analysis_caffeine/utils.py:323: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([self.individuals.data,self.groups.data], keys=["individual","group"])
# /home/janek/Dev/pkdb/notebooks/analysis_caffeine/utils.py:334: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([self.outputs.data,self.timecourses.data], keys=["outputs","timecourses"])
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/generic.py:3111: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
