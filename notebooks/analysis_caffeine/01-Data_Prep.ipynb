# %% [markdown]
# ## Analysis_Caffeine
# This project demonstrated the usage of pkdb for the test substance caffeine.
# ### Data Sources
# - pkdb rest api : "http://0.0.0.0:8000/api/v1/"
#
# ### Outputs:
# - data/processed/outputs.tsv
# - data/processed/timecourses.tsv
# - data/processed/interventions.tsv
# - data/processed/individuals.tsv
# - data/processed/groups.tsv
#
# #### Groups and Individuals
# - data/processed/all_subjects.tsv
#
# ### Merged Dataframes
# - data/processed/all_subjects.tsv
#
# ### Normalized Dataframes
# - data/processed/all_subjects.tsv
#
# ### Changes
# - 11-29-2018 : Started project

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import PkdbModel , Preprocessed
import pandas as pd

# %%
queries = ['outputs','timecourses','interventions','individuals','groups']

# %% [markdown]
# ### Query, Process and Save
# Json data is loaded, transformed to dataframes, preprocessed and saved as tab seperated files.

# %%
for pk_instance in queries:
    pk_instance = PkdbModel(pk_instance)  
    pk_instance.load()
    pk_instance.preprocess()
    pk_instance.save()
    pk_instance.report()
# Out:
# ____________________________________________________________
# Name: outputs
# Loaded: True
# Preprocessed: True
# saved: True
# outputs were succsesfully saved to </home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/outputs.tsv>
# ____________________________________________________________
# Name: timecourses
# Loaded: True
# Preprocessed: True
# saved: True
# timecourses were succsesfully saved to </home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/timecourses.tsv>
# ____________________________________________________________
# Name: interventions
# Loaded: True
# Preprocessed: True
# saved: True
# interventions were succsesfully saved to </home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/interventions.tsv>
# ____________________________________________________________
# Name: individuals
# Loaded: True
# Preprocessed: True
# saved: True
# individuals were succsesfully saved to </home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/individuals.tsv>
# ____________________________________________________________
# Name: groups
# Loaded: True
# Preprocessed: True
# saved: True
# groups were succsesfully saved to </home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/data/1-preprocessed/groups.tsv>

# %% [markdown]
# ### Convert Units

# %%
this_data = PkdbModel('timecourses',destination='1-preprocessed')
this_data.read()
this_data.data.groupby(["pktype","unit"]).count()
# Out:
#                             interventions  tissue  time_unit  time  \
# pktype         unit
# clearance      l/h                      3       3          3     3
#                ml/kg/min                2       2          2     2
# concentration  mg/100ml                 5       5          5     5
#                mmol/l                  33      33         33    33
#                ng/g                     2       2          2     2
#                nmol/l                   6       6          6     6
#                nmol/ml                132     132        132   132
#                pg/ml                   23      23         23    23
#                pmol/l                  53      53         53    53
#                µU/ml                   18      18         18    18
#                µg/ml                  208     208        208   208
#                µmol/l                  56      56         56    56
# cum_amount     µmol                     8       8          8     8
# egp            µmol/kg/min              2       2          2     2
# ra             mg/kg/min               14      14         14    14
#                mg/min                  11      11         11    11
#                µmol/kg/min             29      29         29    29
# rate_cycling   µmol/kg/min              3       3          3     3
# rate_secretion mU/min                   1       1          1     1
#                pmol/min                 1       1          1     1
# ratio          -                       21      21         21    21
#                micro                    6       6          6     6
# rd             mg/kg/min                6       6          6     6
#                mg/min                   3       3          3     3
#                µmol/kg/min             13      13         13    13
#
#                             substance_name  figure  auc_end  group_pk  mean  \
# pktype         unit
# clearance      l/h                       3       3        3         3     3
#                ml/kg/min                 2       2        2         2     2
# concentration  mg/100ml                  5       5        5         5     5
#                mmol/l                   33      33       30        33    33
#                ng/g                      2       2        2         2     0
#                nmol/l                    6       6        4         6     6
#                nmol/ml                 132     132       62         0     0
#                pg/ml                    23      23        8        23    23
#                pmol/l                   53      53       23        53    53
#                µU/ml                    18      18       10        18    18
#                µg/ml                   208     121      187       103   103
#                µmol/l                   56      56       43        56    56
# cum_amount     µmol                      8       8        8         8     8
# egp            µmol/kg/min               2       2        2         2     2
# ra             mg/kg/min                14      14        4        14    14
#                mg/min                   11      11        9        11    11
#                µmol/kg/min              29      29       23        29    29
# rate_cycling   µmol/kg/min               3       3        3         3     3
# rate_secretion mU/min                    1       1        1         1     1
#                pmol/min                  1       1        1         1     1
# ratio          -                        21      20       12        21    16
#                micro                     6       6        6         6     6
# rd             mg/kg/min                 6       6        4         6     6
#                mg/min                    3       3        3         3     3
#                µmol/kg/min              13      13       11        13    13
#
#                             kel  se  cv  individual_pk  value  sd  median  \
# pktype         unit
# clearance      l/h            2   3   3              0      0   0       0
#                ml/kg/min      2   2   2              0      0   0       0
# concentration  mg/100ml       5   5   5              0      0   0       0
#                mmol/l        29  33  33              0      0   0       0
#                ng/g           2   2   0              0      0   2       2
#                nmol/l         4   6   6              0      0   2       0
#                nmol/ml       60   0   0            132    132   0       0
#                pg/ml          8  23  23              0      0   0       0
#                pmol/l        23  53  53              0      0   0       0
#                µU/ml         11  18  18              0      0   0       0
#                µg/ml        177  88  88            105    105  56       0
#                µmol/l        11  56  56              0      0   8       0
# cum_amount     µmol           0   0   0              0      0   0       0
# egp            µmol/kg/min    2   2   2              0      0   0       0
# ra             mg/kg/min      4  14  14              0      0   0       0
#                mg/min         9  11  11              0      0   0       0
#                µmol/kg/min   23  29  29              0      0   0       0
# rate_cycling   µmol/kg/min    3   3   3              0      0   0       0
# rate_secretion mU/min         1   1   1              0      0   0       0
#                pmol/min       1   1   1              0      0   0       0
# ratio          -              3  13  12              0      0  13       7
#                micro          2   6   6              0      0   0       0
# rd             mg/kg/min      4   6   6              0      0   0       0
#                mg/min         3   3   3              0      0   0       0
#                µmol/kg/min   11  13  13              0      0   0       0
#
#                             max  min
# pktype         unit
# clearance      l/h            0    0
#                ml/kg/min      0    0
# concentration  mg/100ml       0    0
#                mmol/l         0    0
#                ng/g           0    0
#                nmol/l         0    0
#                nmol/ml        0    0
#                pg/ml          0    0
#                pmol/l         0    0
#                µU/ml          0    0
#                µg/ml          0    0
#                µmol/l         0    0
# cum_amount     µmol           0    0
# egp            µmol/kg/min    0    0
# ra             mg/kg/min      0    0
#                mg/min         0    0
#                µmol/kg/min    0    0
# rate_cycling   µmol/kg/min    0    0
# rate_secretion mU/min         0    0
#                pmol/min       0    0
# ratio          -              6    6
#                micro          0    0
# rd             mg/kg/min      0    0
#                mg/min         0    0
#                µmol/kg/min    0    0

# %% [markdown]
# ### Merge
#  - merge individuals and groups  --> all_subjects,
#  - merge outputs and timecourses --> all_results,
#  - merge all_results with interventions and individuals  --> individuals_complete,
#  - merge all_results with interventions and groups  --> groups_complete,
#  - merge all_results with interventions and all_subjects -->  all_complete

# %%
prepocessed = Preprocessed()

# %%
prepocessed.read()
prepocessed.merge()
prepocessed.save()
# Out:
# /home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/utils.py:297: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([self.individuals.data,self.groups.data], keys=["individual","group"])
# /home/janekg89/Develop/Pycharm_Projects/pkdb/notebooks/analysis_caffeine/utils.py:308: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([self.outputs.data,self.timecourses.data], keys=["outputs","timecourses"])
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/generic.py:3111: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
